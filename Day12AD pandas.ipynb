# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.sample(10)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6375 2019-03-31 18:50:27 2019-03-31 18:53:53           1      0.59   4.5
# 3369 2019-03-27 11:47:29 2019-03-27 11:56:47           1      1.47   8.5
# 2663 2019-03-03 04:31:42 2019-03-03 04:44:38           1      2.20  11.0
# 3188 2019-03-15 10:22:08 2019-03-15 11:10:37           1      9.18  36.0
# 4699 2019-03-16 01:44:45 2019-03-16 01:53:53           1      0.95   7.5
# 52   2019-03-21 21:30:05 2019-03-21 21:39:03           2      0.90   7.0
# 6093 2019-03-03 15:24:17 2019-03-03 15:55:35           1      9.60  31.5
# 5136 2019-03-21 23:41:55 2019-03-21 23:49:06           1      0.90   6.5
# 734  2019-03-06 20:25:17 2019-03-06 20:36:54           1      1.75   9.5
# 4098 2019-03-04 11:01:27 2019-03-04 11:06:55           1      0.60   5.0
#
#         tip  tolls  total   color      payment                   pickup_zone  \
# 6375   0.00    0.0   5.30   green         cash                Central Harlem
# ...

# %%
df.head(6)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# 1    0.0   9.30  yellow         cash      Upper West Side South
# 2    0.0  14.16  yellow  credit card              Alphabet City
# 3    0.0  36.95  yellow  credit card                  Hudson Sq
# 4    0.0  13.40  yellow  credit card               Midtown East
# ...

# %%
df.tail(9)
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.00
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.50
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.50
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6424  0.00    0.0   9.30  green         cash       Central Harlem
# 6425  0.00    0.0  26.82  green  credit card           Park Slope
# ...

# %%
df['distance'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: distance, Length: 6433, dtype: bool

# %%
df['distance'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(44/6433*100)
# Out:
# 0.6839732628633608

# %%
df.isnull().sum()/6433
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.006840
# pickup_zone        0.004042
# dropoff_zone       0.006995
# pickup_borough     0.004042
# dropoff_borough    0.006995
# dtype: float64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %% [markdown]
# missing data handling
# 1) imputation (fill in the blanks)
#        1) stastical measures
#         2) parameter
#
# 2)  delete data
#       rows
#        columns

# %%
df.drop('pickup_zone',axis=1)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop('pickup_zone',axis=1,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
    df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough'],
#       dtype='object')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop([2,3,6431,6430],axis=0,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index()
# Out:
#       index              pickup             dropoff  passengers  distance  \
# 0         0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60
# 1         1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79
# 2         4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16
# 3         5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49
# 4         6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65
# ...     ...                 ...                 ...         ...       ...
# 6424   6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71
# 6425   6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07
# 6426   6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75
# 6427   6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74
# 6428   6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85
#
#       fare   tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index(drop=True) # its mandatory to apply reset index after deleting the rows from dataframe..
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 3    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 4    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6424 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6425 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6426 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6427 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6428 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df[df['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 5446 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5447 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5448 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5449 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5450 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment                  dropoff_zone  \
# ...
